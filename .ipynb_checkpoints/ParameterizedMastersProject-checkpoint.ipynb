# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import subprocess

# %%
#taxon = "\'Escherichia coli\'"
taxon="\'Saccharomyces cerevisiae\'"

# %%
# Parameters
taxon = "'Deinococcus radiodurans'"

# %%
taxon_file = taxon.lower().replace(" ", "_").replace("\'", "") + "_complete"
subprocess.run(f"""./datasets summary genome taxon {str(taxon)} --assembly-level complete --assembly-source genbank --annotated >  {taxon_file}.json""", shell=True)
p = subprocess.Popen(f"""jq '.total_count' {taxon_file}.json""", stdout=subprocess.PIPE, shell=True)
print(p.stdout.read().decode('ascii').strip())
# Out:
# 8
# New version of client (14.12.0) available at https://ftp.ncbi.nlm.nih.gov/pub/datasets/command-line/LATEST/linux-amd64/datasets

# %%
subprocess.run(f"cat {taxon_file}.json | jq -r '.reports[]| [.accession, .organism.infraspecific_names.strain, .organism.tax_id, .assembly_stats.total_sequence_length, .assembly_stats.gc_percent, .assembly_stats.contig_n50, .annotation_info.stats.gene_counts.total] | @tsv' | head -5 > info_table.tsv", shell=True)
# Out:
# CompletedProcess(args="cat deinococcus_radiodurans_complete.json | jq -r '.reports[]| [.accession, .organism.infraspecific_names.strain, .organism.tax_id, .assembly_stats.total_sequence_length, .assembly_stats.gc_percent, .assembly_stats.contig_n50, .annotation_info.stats.gene_counts.total] | @tsv' | head -5 > info_table.tsv", returncode=0)

# %%
#!cat e_coli_complete.json | jq -r '.reports[]| select(.assembly_stats.contig_n50 > 4500000 ) | .accession' > accession_list.txt
subprocess.run(f"cat {taxon_file}.json | jq -r '.reports[]| .accession' | head -5 > accession_list.txt", shell=True)
# Out:
# CompletedProcess(args="cat deinococcus_radiodurans_complete.json | jq -r '.reports[]| .accession' | head -5 > accession_list.txt", returncode=0)

# %%
subprocess.run(f"./datasets download genome accession --inputfile accession_list.txt --include gbff --filename {taxon_file}.zip", shell=True)
# Out:
# ...
# Downloading: deinococcus_radiodurans_complete.zip    855B 2.54MB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...
# Downloading: deinococcus_radiodurans_complete.zip    4.25kB 379kB/s
# ...

# %%
# !rm README.md
# !rm -r ncbi_dataset
subprocess.run(f"unzip {taxon_file}.zip", shell=True)
# Out:
# Archive:  deinococcus_radiodurans_complete.zip
#   inflating: README.md
#   inflating: ncbi_dataset/data/assembly_data_report.jsonl
#   inflating: ncbi_dataset/data/GCA_008329785.1/genomic.gbff
#   inflating: ncbi_dataset/data/GCA_011604805.1/genomic.gbff
#   inflating: ncbi_dataset/data/GCA_011604825.1/genomic.gbff
#   inflating: ncbi_dataset/data/GCA_020546685.1/genomic.gbff
#   inflating: ncbi_dataset/data/GCA_024138735.1/genomic.gbff
#   inflating: ncbi_dataset/data/dataset_catalog.json
# CompletedProcess(args='unzip deinococcus_radiodurans_complete.zip', returncode=0)

# %%
df = pd.read_table("info_table.tsv")
df.columns = ['Genome', 'Strain', 'Taxonomy Id', 'Sequence length', "GC Percent (%)", "ContigN50", "Gene count"]
df.set_index("Genome", inplace = True)
df["rRNA"]=np.nan
df["tRNA"]=np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_table("info_table.tsv")
#       2 df.columns = ['Genome', 'Strain', 'Taxonomy Id', 'Sequence length', "GC Percent (%)", "ContigN50", "Gene count"]
#       3 df.set_index("Genome", inplace = True)
#
# NameError: name 'pd' is not defined

# %%
for i, row in df.iterrows():
    os.chdir(f"/home/infosebi/Documents/MastersProject/ncbi_dataset/data/{i}")
    p = subprocess.Popen("""cat genomic.gbff | grep rRNAs | awk -F":: " '{ print $2}'""", stdout=subprocess.PIPE, shell=True)
    rRNA = p.stdout.read().decode('ascii').strip()
    p = subprocess.Popen("""cat genomic.gbff | grep tRNAs | awk -F":: " '{ print $2}'""", stdout=subprocess.PIPE, shell=True)
    tRNA = p.stdout.read().strip().decode('ascii')
    df.at[i, "rRNA"] = rRNA
    df.at[i, "tRNA"] = tRNA
os.chdir("/home/infosebi/Documents/MastersProject")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i, row in df.iterrows():
#       2     os.chdir(f"/home/infosebi/Documents/MastersProject/ncbi_dataset/data/{i}")
#       3     p = subprocess.Popen("""cat genomic.gbff | grep rRNAs | awk -F":: " '{ print $2}'""", stdout=subprocess.PIPE, shell=True)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
#papermill stuff -> path, taxon, maybe selection?
#import pyspark
# create spark dataframe (pandas to spark)
#genbank file parser
#is it possible to have interaction in jupyter notebook
#install Eggnog database -> run Eggnog annotation on gbff file.
#google collab (vs-code, github repo)
#circus (input-data?)
